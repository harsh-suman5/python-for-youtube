# %%
# how do i create plots in pandas
import pandas as pd
import matplotlib.pyplot as plt

# %%
air_quality = pd.read_csv(r"D:\python\air_quality_no2.csv")
air_quality.head()
# Out:
#               datetime  station_antwerp  station_paris  station_london
# 0  2019-05-07 02:00:00              NaN            NaN            23.0
# 1  2019-05-07 03:00:00             50.5           25.0            19.0
# 2  2019-05-07 04:00:00             45.0           27.7            19.0
# 3  2019-05-07 05:00:00              NaN           50.4            16.0
# 4  2019-05-07 06:00:00              NaN           61.9             NaN

# %%
air_quality.plot()
# Out:
# <Axes: >

# %%
air_quality['station_london'].plot()
# Out:
# <Axes: >

# %%
air_quality.plot.scatter(x='station_london', y='station_paris' ,alpha=0.5)
# Out:
# <Axes: xlabel='station_london', ylabel='station_paris'>

# %%
air_quality.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
air_quality['station_antwerp'].plot.bar()
# Out:
# <Axes: >

# %%
air_quality.plot.box()
# Out:
# <Axes: >

# %%
air_quality['london_mg_per_cubic'] = air_quality['station_london']*1.882
air_quality.head()
# Out:
#               datetime  station_antwerp  station_paris  station_london  \
# 0  2019-05-07 02:00:00              NaN            NaN            23.0
# 1  2019-05-07 03:00:00             50.5           25.0            19.0
# 2  2019-05-07 04:00:00             45.0           27.7            19.0
# 3  2019-05-07 05:00:00              NaN           50.4            16.0
# 4  2019-05-07 06:00:00              NaN           61.9             NaN
#
#    london_mg_per_cubic
# 0               43.286
# 1               35.758
# 2               35.758
# 3               30.112
# 4                  NaN

# %%
air_quality['london_mg_per_cubic'].plot()
# Out:
# <Axes: >

# %%
air_quality['ratio_antwerp_paris'] =  air_quality['station_antwerp']/air_quality['station_paris']
air_quality.head()
# Out:
#               datetime  station_antwerp  station_paris  station_london  \
# 0  2019-05-07 02:00:00              NaN            NaN            23.0
# 1  2019-05-07 03:00:00             50.5           25.0            19.0
# 2  2019-05-07 04:00:00             45.0           27.7            19.0
# 3  2019-05-07 05:00:00              NaN           50.4            16.0
# 4  2019-05-07 06:00:00              NaN           61.9             NaN
#
#    london_mg_per_cubic  ratio_antwerp_paris
# 0               43.286                  NaN
# 1               35.758             2.020000
# 2               35.758             1.624549
# 3               30.112                  NaN
# 4                  NaN                  NaN

# %%
air_quality['station_antwerp'].plot()
# Out:
# <Axes: >

# %%
air_quality_renamed = air_quality.rename(
    columns={
        "station_london": "mumbai",
        "station_paris" :"delhi"
    }
)
air_quality_renamed.head()
# Out:
#               datetime  station_antwerp  delhi  mumbai  london_mg_per_cubic  \
# 0  2019-05-07 02:00:00              NaN    NaN    23.0               43.286
# 1  2019-05-07 03:00:00             50.5   25.0    19.0               35.758
# 2  2019-05-07 04:00:00             45.0   27.7    19.0               35.758
# 3  2019-05-07 05:00:00              NaN   50.4    16.0               30.112
# 4  2019-05-07 06:00:00              NaN   61.9     NaN                  NaN
#
#    ratio_antwerp_paris
# 0                  NaN
# 1             2.020000
# 2             1.624549
# 3                  NaN
# 4                  NaN

# %%
air_quality.head()
# Out:
#               datetime  station_antwerp  station_paris  station_london  \
# 0  2019-05-07 02:00:00              NaN            NaN            23.0
# 1  2019-05-07 03:00:00             50.5           25.0            19.0
# 2  2019-05-07 04:00:00             45.0           27.7            19.0
# 3  2019-05-07 05:00:00              NaN           50.4            16.0
# 4  2019-05-07 06:00:00              NaN           61.9             NaN
#
#    london_mg_per_cubic  ratio_antwerp_paris
# 0               43.286                  NaN
# 1               35.758             2.020000
# 2               35.758             1.624549
# 3               30.112                  NaN
# 4                  NaN                  NaN

# %%
air_quality_renamed.plot()
# Out:
# <Axes: >

# %%
mean = air_quality['station_london'].mean()
print("the mean value of  station_london is: ",mean)
# Out:
# the mean value of  station_london is:  24.777089783281735

# %%
air_quality[["station_london","station_paris"]].describe()
# Out:
#        station_london  station_paris
# count      969.000000    1004.000000
# mean        24.777090      27.740538
# std         11.214377      15.285746
# min          0.000000       0.000000
# 25%         19.000000      16.500000
# 50%         25.000000      24.150000
# 75%         31.000000      35.925000
# max         97.000000      97.000000
