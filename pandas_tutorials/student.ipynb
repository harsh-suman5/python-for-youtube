# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.DataFrame({
    "name":["RAVI","HARISH","SHUBHAM"],
    "roll_no":['1','2','3'],
    "course":["AI&ML","CSE","ECE"],
    "session":["2024-28","2022-26","2023-2027"]
})

# %%
data
# Out:
#       name  roll_no course    session
# 0     RAVI        1  AI&ML    2024-28
# 1   HARISH        2    CSE    2022-26
# 2  SHUBHAM        3    ECE  2023-2027

# %%
plt.plot(data['name'],data['roll_no'])
