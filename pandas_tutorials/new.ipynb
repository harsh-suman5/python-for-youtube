# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.Series(['male','female','female','male','male','female'],name=  'gender')
data
# Out:
# 0      male
# 1    female
# 2    female
# 3      male
# 4      male
# 5    female
# Name: gender, dtype: object

# %%
data.max()
# Out:
# <bound method Series.max of 0      male
# 1    female
# 2    female
# 3      male
# 4      male
# 5    female
# Name: gender, dtype: object>

# %%
data.min()
# Out:
# 'female'

# %%
plt.title('gender data vizualization')
plt.plot(data)

# %%
data.describe()
# Out:
# count        6
# unique       2
# top       male
# freq         3
# Name: gender, dtype: object
