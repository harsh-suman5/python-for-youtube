# %%
list = [1,2,3,4, 13,12, 19, 5 ,7,100,120,23,60]
# list.append(5)
list
# Out:
# [1, 2, 3, 4, 13, 12, 19, 5, 7, 100, 120, 23, 60]

# %%
list1 = [5,6,7,8]
list1.extend(list1[1:])
list1.extend(list1[0:2])
list1.append(list1[1:3])
list1
# Out:
# [5, 6, 7, 8, 6, 7, 8, 5, 6, [6, 7]]

# %%
list2 = [9,10,11,12]
list2.insert(1,3)
list2.insert(2,4)

list2
# Out:
# [9, 3, 4, 10, 11, 12, 13]

# %%
list.pop(2)
# Out:
# 3

# %%
list
# Out:
# [1, 2, 3, 4, 5]

# %%
list.sort() # used for sorting the list
list
# Out:
# [1, 2, 3, 4, 5, 7, 12, 13, 19, 23, 60, 100, 120]

# %%
list.reverse() #used for reverse the list
list
# Out:
# [120, 100, 60, 23, 19, 13, 12, 7, 5, 4, 3, 2, 1]

# %%
list.copy()
list
# Out:
# [120, 100, 60, 23, 19, 13, 12, 7, 5, 4, 3, 2, 1]

# %%
# count,index,reverse,append,sort,pop

animals = ['dog', 'cat', 'lion','lion' 'tiger', 'horse', 'zebra']
animals.count('lion')
animals.index('zebra')
# animals.reverse()

animals
animals.append('tiger')
animals
animals.count('tiger')
animals
animals.sort()
animals
animals.pop(6)
animals
# Out:
# ['cat', 'dog', 'horse', 'lion', 'liontiger', 'tiger']

# %%
stack = [2,3,4] # list as a stack
stack.append(5)
stack.append(6)
stack
# Out:
# [2, 3, 4, 5, 6]

# %%
stack.pop()
stack
# Out:
# [2, 3, 4, 5]

# %%
stack.pop()
# Out:
# 5

# %%
stack
# Out:
# [2, 3, 4]

# %%
from collections import deque # list as a queue
queue = deque(['lion','tiger','cat'])
queue.append('zebra')
queue
queue.popleft()
queue
queue.popleft()
queue
# Out:
# deque(['cat', 'zebra'])

# %%
a = []
for b in range(10):
    a.append(b**2)
a
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]
